# %%
# %pip install -U fastai
# Out:
# Collecting fastai
#   Using cached fastai-2.7.12-py3-none-any.whl (233 kB)
# Requirement already satisfied: pip in /opt/homebrew/lib/python3.11/site-packages (from fastai) (23.1.2)
# Requirement already satisfied: packaging in /Users/yitzi/Library/Python/3.11/lib/python/site-packages (from fastai) (23.1)
# Collecting fastdownload<2,>=0.0.5 (from fastai)
#   Using cached fastdownload-0.0.7-py3-none-any.whl (12 kB)
# Collecting fastcore<1.6,>=1.5.29 (from fastai)
#   Using cached fastcore-1.5.29-py3-none-any.whl (67 kB)
# Collecting torchvision>=0.8.2 (from fastai)
#   Using cached torchvision-0.15.2-cp311-cp311-macosx_11_0_arm64.whl (1.4 MB)
# Collecting matplotlib (from fastai)
#   Using cached matplotlib-3.7.1-cp311-cp311-macosx_11_0_arm64.whl (7.3 MB)
# Collecting pandas (from fastai)
#   Downloading pandas-2.0.1-cp311-cp311-macosx_11_0_arm64.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 280.8 kB/s eta 0:00:0000:0100:02
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.11/site-packages (from fastai) (2.31.0)
# Collecting pyyaml (from fastai)
#   Downloading PyYAML-6.0-cp311-cp311-macosx_11_0_arm64.whl (167 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.5/167.5 kB 203.5 kB/s eta 0:00:00a 0:00:01
# Collecting fastprogress>=0.2.4 (from fastai)
#   Downloading fastprogress-1.0.3-py3-none-any.whl (12 kB)
# Collecting pillow>6.0.0 (from fastai)
#   Downloading Pillow-9.5.0-cp311-cp311-macosx_11_0_arm64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 107.7 kB/s eta 0:00:0000:0100:01
# Collecting scikit-learn (from fastai)
#   Downloading scikit_learn-1.2.2-cp311-cp311-macosx_12_0_arm64.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 96.7 kB/s eta 0:00:0000:0100:03m
# Collecting scipy (from fastai)
#   Downloading scipy-1.10.1-cp311-cp311-macosx_12_0_arm64.whl (28.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.7/28.7 MB 318.7 kB/s eta 0:00:0000:0100:03
# Collecting spacy<4 (from fastai)
#   Downloading spacy-3.5.3-cp311-cp311-macosx_11_0_arm64.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 269.6 kB/s eta 0:00:0000:0100:01
# Collecting torch<2.1,>=1.7 (from fastai)
#   Downloading torch-2.0.1-cp311-none-macosx_11_0_arm64.whl (55.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 MB 347.7 kB/s eta 0:00:0000:0100:04
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy<4->fastai)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy<4->fastai)
#   Downloading spacy_loggers-1.0.4-py3-none-any.whl (11 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy<4->fastai)
#   Downloading murmurhash-1.0.9-cp311-cp311-macosx_11_0_arm64.whl (18 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy<4->fastai)
#   Downloading cymem-2.0.7-cp311-cp311-macosx_11_0_arm64.whl (30 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy<4->fastai)
#   Downloading preshed-3.0.8-cp311-cp311-macosx_11_0_arm64.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 225.9 kB/s eta 0:00:00a 0:00:01
# Collecting thinc<8.2.0,>=8.1.8 (from spacy<4->fastai)
#   Downloading thinc-8.1.10-cp311-cp311-macosx_11_0_arm64.whl (770 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.0/770.0 kB 327.8 kB/s eta 0:00:00a 0:00:01
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy<4->fastai)
#   Downloading wasabi-1.1.1-py3-none-any.whl (27 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy<4->fastai)
#   Downloading srsly-2.4.6-cp311-cp311-macosx_11_0_arm64.whl (487 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.6/487.6 kB 369.4 kB/s eta 0:00:0000:0100:01
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy<4->fastai)
#   Downloading catalogue-2.0.8-py3-none-any.whl (17 kB)
# Collecting typer<0.8.0,>=0.3.0 (from spacy<4->fastai)
#   Downloading typer-0.7.0-py3-none-any.whl (38 kB)
# Collecting pathy>=0.10.0 (from spacy<4->fastai)
#   Downloading pathy-0.10.1-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 301.5 kB/s eta 0:00:00a 0:00:01
# Collecting smart-open<7.0.0,>=5.2.1 (from spacy<4->fastai)
#   Downloading smart_open-6.3.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 89.0 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/homebrew/lib/python3.11/site-packages (from spacy<4->fastai) (4.65.0)
# Collecting numpy>=1.15.0 (from spacy<4->fastai)
#   Downloading numpy-1.24.3-cp311-cp311-macosx_11_0_arm64.whl (13.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 175.7 kB/s eta 0:00:0000:0100:03
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 (from spacy<4->fastai)
#   Downloading pydantic-1.10.8-cp311-cp311-macosx_11_0_arm64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 303.6 kB/s eta 0:00:0000:0100:01
# Collecting jinja2 (from spacy<4->fastai)
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 220.5 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: setuptools in /opt/homebrew/lib/python3.11/site-packages (from spacy<4->fastai) (67.6.1)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy<4->fastai)
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 194.9 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests->fastai) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests->fastai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests->fastai) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests->fastai) (2023.5.7)
# Collecting filelock (from torch<2.1,>=1.7->fastai)
#   Downloading filelock-3.12.0-py3-none-any.whl (10 kB)
# Collecting typing-extensions (from torch<2.1,>=1.7->fastai)
#   Downloading typing_extensions-4.6.2-py3-none-any.whl (31 kB)
# Collecting sympy (from torch<2.1,>=1.7->fastai)
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 273.0 kB/s eta 0:00:0000:0100:01
# Collecting networkx (from torch<2.1,>=1.7->fastai)
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 409.5 kB/s eta 0:00:00a 0:00:01
# Collecting contourpy>=1.0.1 (from matplotlib->fastai)
#   Downloading contourpy-1.0.7-cp311-cp311-macosx_11_0_arm64.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.7/229.7 kB 252.2 kB/s eta 0:00:00a 0:00:01
# Collecting cycler>=0.10 (from matplotlib->fastai)
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->fastai)
#   Downloading fonttools-4.39.4-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 242.3 kB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.0.1 (from matplotlib->fastai)
#   Downloading kiwisolver-1.4.4-cp311-cp311-macosx_11_0_arm64.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 212.9 kB/s eta 0:00:00a 0:00:01
# Collecting pyparsing>=2.3.1 (from matplotlib->fastai)
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 275.6 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /Users/yitzi/Library/Python/3.11/lib/python/site-packages (from matplotlib->fastai) (2.8.2)
# Collecting pytz>=2020.1 (from pandas->fastai)
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.3/502.3 kB 288.1 kB/s eta 0:00:00a 0:00:01
# Collecting tzdata>=2022.1 (from pandas->fastai)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 360.6 kB/s eta 0:00:00a 0:00:01
# Collecting joblib>=1.1.1 (from scikit-learn->fastai)
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 302.9 kB/s eta 0:00:00a 0:00:01
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->fastai)
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: six>=1.5 in /Users/yitzi/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.7->matplotlib->fastai) (1.16.0)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.2.0,>=8.1.8->spacy<4->fastai)
#   Downloading blis-0.7.9-cp311-cp311-macosx_11_0_arm64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 314.4 kB/s eta 0:00:0000:0100:01
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.2.0,>=8.1.8->spacy<4->fastai)
#   Downloading confection-0.0.4-py3-none-any.whl (32 kB)
# Collecting click<9.0.0,>=7.1.1 (from typer<0.8.0,>=0.3.0->spacy<4->fastai)
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->spacy<4->fastai)
#   Downloading MarkupSafe-2.1.2-cp311-cp311-macosx_10_9_universal2.whl (17 kB)
# Collecting mpmath>=0.19 (from sympy->torch<2.1,>=1.7->fastai)
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 242.5 kB/s eta 0:00:0000:0100:01
# Installing collected packages: pytz, mpmath, cymem, wasabi, tzdata, typing-extensions, threadpoolctl, sympy, spacy-loggers, spacy-legacy, smart-open, pyyaml, pyparsing, pillow, numpy, networkx, murmurhash, MarkupSafe, langcodes, kiwisolver, joblib, fonttools, filelock, fastprogress, fastcore, cycler, click, catalogue, typer, srsly, scipy, pydantic, preshed, pandas, jinja2, fastdownload, contourpy, blis, torch, scikit-learn, pathy, matplotlib, confection, torchvision, thinc, spacy, fastai
# Successfully installed MarkupSafe-2.1.2 blis-0.7.9 catalogue-2.0.8 click-8.1.3 confection-0.0.4 contourpy-1.0.7 cycler-0.11.0 cymem-2.0.7 fastai-2.7.12 fastcore-1.5.29 fastdownload-0.0.7 fastprogress-1.0.3 filelock-3.12.0 fonttools-4.39.4 jinja2-3.1.2 joblib-1.2.0 kiwisolver-1.4.4 langcodes-3.3.0 matplotlib-3.7.1 mpmath-1.3.0 murmurhash-1.0.9 networkx-3.1 numpy-1.24.3 pandas-2.0.1 pathy-0.10.1 pillow-9.5.0 preshed-3.0.8 pydantic-1.10.8 pyparsing-3.0.9 pytz-2023.3 pyyaml-6.0 scikit-learn-1.2.2 scipy-1.10.1 smart-open-6.3.0 spacy-3.5.3 spacy-legacy-3.0.12 spacy-loggers-1.0.4 srsly-2.4.6 sympy-1.12 thinc-8.1.10 threadpoolctl-3.1.0 torch-2.0.1 torchvision-0.15.2 typer-0.7.0 typing-extensions-4.6.2 tzdata-2023.3 wasabi-1.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -U duckduckgo_search
# Out:
# Collecting duckduckgo_search
#   Downloading duckduckgo_search-3.6.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: click>=8.1.3 in /opt/homebrew/lib/python3.11/site-packages (from duckduckgo_search) (8.1.3)
# Collecting lxml>=4.9.2 (from duckduckgo_search)
#   Downloading lxml-4.9.2.tar.gz (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 191.9 kB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting httpx[http2]>=0.24.1 (from duckduckgo_search)
#   Downloading httpx-0.24.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 244.5 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests>=2.31.0 in /opt/homebrew/lib/python3.11/site-packages (from duckduckgo_search) (2.31.0)
# Requirement already satisfied: certifi in /opt/homebrew/lib/python3.11/site-packages (from httpx[http2]>=0.24.1->duckduckgo_search) (2023.5.7)
# Collecting httpcore<0.18.0,>=0.15.0 (from httpx[http2]>=0.24.1->duckduckgo_search)
#   Downloading httpcore-0.17.2-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 215.9 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: idna in /opt/homebrew/lib/python3.11/site-packages (from httpx[http2]>=0.24.1->duckduckgo_search) (3.4)
# Collecting sniffio (from httpx[http2]>=0.24.1->duckduckgo_search)
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting h2<5,>=3 (from httpx[http2]>=0.24.1->duckduckgo_search)
#   Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 298.0 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.31.0->duckduckgo_search) (3.1.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.31.0->duckduckgo_search) (2.0.2)
# Collecting hyperframe<7,>=6.0 (from h2<5,>=3->httpx[http2]>=0.24.1->duckduckgo_search)
#   Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Collecting hpack<5,>=4.0 (from h2<5,>=3->httpx[http2]>=0.24.1->duckduckgo_search)
#   Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Collecting h11<0.15,>=0.13 (from httpcore<0.18.0,>=0.15.0->httpx[http2]>=0.24.1->duckduckgo_search)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 224.6 kB/s eta 0:00:00a 0:00:01
# Collecting anyio<5.0,>=3.0 (from httpcore<0.18.0,>=0.15.0->httpx[http2]>=0.24.1->duckduckgo_search)
#   Downloading anyio-3.7.0-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 141.2 kB/s eta 0:00:00a 0:00:01
# Building wheels for collected packages: lxml
#   Building wheel for lxml (setup.py) ... done
#   Created wheel for lxml: filename=lxml-4.9.2-cp311-cp311-macosx_13_0_arm64.whl size=1641941 sha256=71b3ef2af5f894bbad968de1fc5bd28e3e68dfa5ff70b1da0bedd02e4a3d87bf
#   Stored in directory: /Users/yitzi/Library/Caches/pip/wheels/fb/5b/f7/0a27880b4a007daeff53a196d01901627f640392b7e76e76e5
# Successfully built lxml
# Installing collected packages: sniffio, lxml, hyperframe, hpack, h11, h2, anyio, httpcore, httpx, duckduckgo_search
# Successfully installed anyio-3.7.0 duckduckgo_search-3.6.0 h11-0.14.0 h2-4.1.0 hpack-4.0.0 httpcore-0.17.2 httpx-0.24.1 hyperframe-6.0.1 lxml-4.9.2 sniffio-1.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from duckduckgo_search import ddg_images
from fastcore.all import *

def search_images(term, max_images=30):
    print(f"Searching for {term}...")
    return L(ddg_images(term, max_results=max_images)).itemgot('image')

# %%
urls = search_images('bird photos', max_images=1)
urls[0]
# Out:
# Searching for bird photos...
# /opt/homebrew/lib/python3.11/site-packages/duckduckgo_search/compat.py:60: UserWarning: ddg_images is deprecated. Use DDGS().images() generator
#   warnings.warn("ddg_images is deprecated. Use DDGS().images() generator")
# /opt/homebrew/lib/python3.11/site-packages/duckduckgo_search/compat.py:64: UserWarning: parameter page is deprecated
#   warnings.warn("parameter page is deprecated")
# /opt/homebrew/lib/python3.11/site-packages/duckduckgo_search/compat.py:66: UserWarning: parameter max_results is deprecated
#   warnings.warn("parameter max_results is deprecated")
# 'http://www.wallpapergeeks.com/wp-content/uploads/2014/02/Colorful-Bird-Perched-Wallpaper.jpg'

# %%
from fastdownload import download_url
dest = 'bird.jpg'
download_url(urls[0], dest)

from fastai.vision.all import *
im = Image.open(dest)
im.to_thumb(128,128)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='835584' class='' max='828720' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.83% [835584/828720 00:04&lt;00:00]
#     </div>
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
download_url(search_images('forest photos', max_images=1)[0], 'forest.jpg')
Image.open('forest.jpg').to_thumb(128,128)
# Out:
# Searching for forest photos...
# /opt/homebrew/lib/python3.11/site-packages/duckduckgo_search/compat.py:60: UserWarning: ddg_images is deprecated. Use DDGS().images() generator
#   warnings.warn("ddg_images is deprecated. Use DDGS().images() generator")
# /opt/homebrew/lib/python3.11/site-packages/duckduckgo_search/compat.py:64: UserWarning: parameter page is deprecated
#   warnings.warn("parameter page is deprecated")
# /opt/homebrew/lib/python3.11/site-packages/duckduckgo_search/compat.py:66: UserWarning: parameter max_results is deprecated
#   warnings.warn("parameter max_results is deprecated")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='761856' class='' max='758477' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.45% [761856/758477 00:03&lt;00:00]
#     </div>
# <PIL.Image.Image image mode=RGB size=128x80>

# %%
searches = 'forest', 'bird'
path = Path('bird_or_not')
from time import sleep

for o in searches:
    dest = (path/o)
    dest.mkdir(exist_ok=True, parents=True)
    download_images(dest, urls=search_images(f'{o} photo'))
    sleep(10)
    download_images(dest, urls=search_images(f'{o} sun photo'))
    sleep(10)
    download_images(dest, urls=search_images(f'{o} shade photo'))
    sleep(10)

    resize_images(path/o, max_size=400, dest=path/o)
# Out:
# Searching for forest photo...
# /opt/homebrew/lib/python3.11/site-packages/duckduckgo_search/compat.py:60: UserWarning: ddg_images is deprecated. Use DDGS().images() generator
#   warnings.warn("ddg_images is deprecated. Use DDGS().images() generator")
# /opt/homebrew/lib/python3.11/site-packages/duckduckgo_search/compat.py:64: UserWarning: parameter page is deprecated
#   warnings.warn("parameter page is deprecated")
# /opt/homebrew/lib/python3.11/site-packages/duckduckgo_search/compat.py:66: UserWarning: parameter max_results is deprecated
#   warnings.warn("parameter max_results is deprecated")
# Searching for forest sun photo...
# Searching for forest shade photo...
# Searching for bird photo...
# Searching for bird sun photo...
# Searching for bird shade photo...

# %%
failed = verify_images(get_image_files(path))
failed.map(Path.unlink);
len(failed)
# Out:
# 24

# %%
dls = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=[Resize(192, method='squish')]
).dataloaders(path, bs=32)

dls.show_batch(max_n=6)

# %%
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(3)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /Users/yitzi/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [01:45<00:00, 444kB/s]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.827471</td>
#       <td>0.357206</td>
#       <td>0.185185</td>
#       <td>00:30</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.259898</td>
#       <td>0.086452</td>
#       <td>0.037037</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.173368</td>
#       <td>0.140118</td>
#       <td>0.074074</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.150210</td>
#       <td>0.151094</td>
#       <td>0.074074</td>
#       <td>00:04</td>
#     </tr>
#   </tbody>
# </table>

# %%
is_bird,_,probs = learn.predict(PILImage.create('bird.jpg'))
(f"This is a: {is_bird}.")
(f"Probability it's a bird: {probs[0]:.4f}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# "Probability it's a bird: 0.9992"
